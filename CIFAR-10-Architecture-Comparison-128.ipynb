# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import History
import time
import warnings
warnings.filterwarnings('ignore')

print("TF version:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# 2026-04-25 19:06:31.381862: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777143991.592281      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777143991.660762      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777143992.191940      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777143992.191974      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777143992.191977      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777143992.191980      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TF version: 2.19.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
# Cell 2: Load and preprocess CIFAR-10
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Normalize
x_train = x_train.astype('float32') / 255.0
x_test  = x_test.astype('float32')  / 255.0

# One-hot encode
y_train_cat = to_categorical(y_train, 10)
y_test_cat  = to_categorical(y_test,  10)

CLASS_NAMES = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

print("Train shape:", x_train.shape)
print("Test shape :", x_test.shape)

# Visualize a few samples
fig, axes = plt.subplots(2, 5, figsize=(12, 5))
for i, ax in enumerate(axes.flat):
    ax.imshow(x_train[i])
    ax.set_title(CLASS_NAMES[y_train[i][0]])
    ax.axis('off')
plt.suptitle("CIFAR-10 Sample Images")
plt.tight_layout()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Train shape: (50000, 32, 32, 3)
# Test shape : (10000, 32, 32, 3)

# %%
# Cell 3: Define all three architectures

# ── Model 1: VGG-style CNN ──────────────────────────────────────
def build_vgg(input_shape=(32,32,3), num_classes=10):
    model = models.Sequential([
        # Block 1
        layers.Conv2D(64, 3, padding='same', activation='relu', input_shape=input_shape),
        layers.Conv2D(64, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(2, 2),
        layers.BatchNormalization(),
        layers.Dropout(0.25),

        # Block 2
        layers.Conv2D(128, 3, padding='same', activation='relu'),
        layers.Conv2D(128, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(2, 2),
        layers.BatchNormalization(),
        layers.Dropout(0.25),

        # Block 3
        layers.Conv2D(256, 3, padding='same', activation='relu'),
        layers.Conv2D(256, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(2, 2),
        layers.BatchNormalization(),
        layers.Dropout(0.4),

        # Classifier
        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ], name='VGG_style')
    return model

# ── Model 2: ResNet-style (with residual blocks) ────────────────
def residual_block(x, filters, downsample=False):
    shortcut = x
    stride = 2 if downsample else 1

    x = layers.Conv2D(filters, 3, strides=stride, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, strides=1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    if downsample or shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, 1, strides=stride, padding='same', use_bias=False)(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Add()([x, shortcut])
    x = layers.ReLU()(x)
    return x

def build_resnet(input_shape=(32,32,3), num_classes=10):
    inputs = keras.Input(shape=input_shape)
    x = layers.Conv2D(64, 3, padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = residual_block(x, 64)
    x = residual_block(x, 64)
    x = residual_block(x, 128, downsample=True)
    x = residual_block(x, 128)
    x = residual_block(x, 256, downsample=True)
    x = residual_block(x, 256)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    return keras.Model(inputs, outputs, name='ResNet_style')

# ── Model 3: MobileNet-style (depthwise separable convolutions) ─
def build_mobilenet(input_shape=(32,32,3), num_classes=10):
    def dw_block(x, filters, stride=1):
        x = layers.DepthwiseConv2D(3, strides=stride, padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)
        x = layers.Conv2D(filters, 1, padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)
        return x

    inputs = keras.Input(shape=input_shape)
    x = layers.Conv2D(32, 3, strides=1, padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = dw_block(x, 64)
    x = dw_block(x, 128, stride=2)
    x = dw_block(x, 128)
    x = dw_block(x, 256, stride=2)
    x = dw_block(x, 256)
    x = dw_block(x, 512)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    return keras.Model(inputs, outputs, name='MobileNet_style')

# Test builds
for build_fn in [build_vgg, build_resnet, build_mobilenet]:
    m = build_fn()
    print(f"{m.name}: {m.count_params():,} parameters")
# Out:
# I0000 00:00:1777144027.719168      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1777144027.725166      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# VGG_style: 3,249,994 parameters
# ResNet_style: 2,782,154 parameters
# MobileNet_style: 278,730 parameters

# %%
# Cell 4: Helper function for training

def compile_model(model, lr=0.001):
    model.compile(
        optimizer=keras.optimizers.Adam(lr),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

def train_model(model, x_tr, y_tr, x_val, y_val, epochs=30, batch_size=64, label=""):
    callbacks = [
        keras.callbacks.ReduceLROnPlateau(patience=3, factor=0.5, verbose=0),
        keras.callbacks.EarlyStopping(patience=8, restore_best_weights=True, verbose=0)
    ]
    start = time.time()
    history = model.fit(
        x_tr, y_tr,
        validation_data=(x_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=callbacks,
        verbose=1
    )
    elapsed = time.time() - start
    test_loss, test_acc = model.evaluate(x_val, y_val, verbose=0)
    print(f"\n[{label}] Test Acc: {test_acc:.4f} | Time: {elapsed:.1f}s")
    return history, test_acc, elapsed

print("Helper functions ready ✓")
# Out:
# Helper functions ready ✓

# %%
# Cell 5: Strategy 1 — Full Dataset (baseline) with Data Augmentation

results = {}   # store all results here

EPOCHS = 30

# Data augmentation — reduces overfitting, especially for VGG
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)
datagen.fit(x_train)

for name, build_fn in [('VGG', build_vgg), ('ResNet', build_resnet), ('MobileNet', build_mobilenet)]:
    print(f"\n{'='*50}")
    print(f"Training {name} | Strategy 1: Full Dataset (with augmentation)")
    print('='*50)
    model = build_fn()
    compile_model(model)
    callbacks = [
        keras.callbacks.ReduceLROnPlateau(patience=3, factor=0.5, verbose=0),
        keras.callbacks.EarlyStopping(patience=8, restore_best_weights=True, verbose=0)
    ]
    start = time.time()
    hist = model.fit(
        datagen.flow(x_train, y_train_cat, batch_size=128),
        validation_data=(x_test, y_test_cat),
        epochs=EPOCHS,
        callbacks=callbacks,
        verbose=1
    )
    elapsed = time.time() - start
    _, acc = model.evaluate(x_test, y_test_cat, verbose=0)
    print(f"\n[{name}_S1] Test Acc: {acc:.4f} | Time: {elapsed:.1f}s")
    results[f"{name}_S1"] = {'history': hist, 'acc': acc, 'time': elapsed}

print("\nStrategy 1 complete ✓")
# Out:
# ==================================================
# Training VGG | Strategy 1: Full Dataset (with augmentation)
# ==================================================
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777144033.327070      73 service.cc:152] XLA service 0x7efbb4003880 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1777144033.327124      73 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1777144033.327131      73 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1777144034.040943      73 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   3/391 ━━━━━━━━━━━━━━━━━━━━ 23s 61ms/step - accuracy: 0.1137 - loss: 3.8946
# I0000 00:00:1777144042.591237      73 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 48s 90ms/step - accuracy: 0.3158 - loss: 2.0926 - val_accuracy: 0.1441 - val_loss: 8.6039 - learning_rate: 0.0010
# Epoch 2/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.5285 - loss: 1.3168 - val_accuracy: 0.5939 - val_loss: 1.2075 - learning_rate: 0.0010
# Epoch 3/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.6178 - loss: 1.0773 - val_accuracy: 0.5319 - val_loss: 1.5348 - learning_rate: 0.0010
# Epoch 4/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.6687 - loss: 0.9431 - val_accuracy: 0.6669 - val_loss: 1.0366 - learning_rate: 0.0010
# Epoch 5/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7031 - loss: 0.8688 - val_accuracy: 0.7440 - val_loss: 0.7388 - learning_rate: 0.0010
# Epoch 6/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7339 - loss: 0.7810 - val_accuracy: 0.7474 - val_loss: 0.7250 - learning_rate: 0.0010
# Epoch 7/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7439 - loss: 0.7435 - val_accuracy: 0.7733 - val_loss: 0.6836 - learning_rate: 0.0010
# Epoch 8/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7560 - loss: 0.7140 - val_accuracy: 0.7575 - val_loss: 0.7481 - learning_rate: 0.0010
# Epoch 9/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7747 - loss: 0.6572 - val_accuracy: 0.8053 - val_loss: 0.5896 - learning_rate: 0.0010
# Epoch 10/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7866 - loss: 0.6265 - val_accuracy: 0.8124 - val_loss: 0.5748 - learning_rate: 0.0010
# Epoch 11/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.7969 - loss: 0.6060 - val_accuracy: 0.7438 - val_loss: 0.8222 - learning_rate: 0.0010
# Epoch 12/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.8022 - loss: 0.5769 - val_accuracy: 0.8304 - val_loss: 0.5051 - learning_rate: 0.0010
# Epoch 13/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.8073 - loss: 0.5682 - val_accuracy: 0.8196 - val_loss: 0.5417 - learning_rate: 0.0010
# Epoch 14/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.8200 - loss: 0.5356 - val_accuracy: 0.8054 - val_loss: 0.5838 - learning_rate: 0.0010
# Epoch 15/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.8242 - loss: 0.5222 - val_accuracy: 0.8245 - val_loss: 0.5401 - learning_rate: 0.0010
# Epoch 16/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.8445 - loss: 0.4615 - val_accuracy: 0.8523 - val_loss: 0.4505 - learning_rate: 5.0000e-04
# Epoch 17/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.8541 - loss: 0.4251 - val_accuracy: 0.8114 - val_loss: 0.6090 - learning_rate: 5.0000e-04
# Epoch 18/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.8573 - loss: 0.4151 - val_accuracy: 0.8659 - val_loss: 0.4242 - learning_rate: 5.0000e-04
# Epoch 19/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 63ms/step - accuracy: 0.8662 - loss: 0.3890 - val_accuracy: 0.8736 - val_loss: 0.3882 - learning_rate: 5.0000e-04
# Epoch 20/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.8702 - loss: 0.3821 - val_accuracy: 0.8696 - val_loss: 0.4053 - learning_rate: 5.0000e-04
# Epoch 21/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.8728 - loss: 0.3763 - val_accuracy: 0.8665 - val_loss: 0.4182 - learning_rate: 5.0000e-04
# Epoch 22/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.8762 - loss: 0.3643 - val_accuracy: 0.8705 - val_loss: 0.3922 - learning_rate: 5.0000e-04
# Epoch 23/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.8870 - loss: 0.3334 - val_accuracy: 0.8809 - val_loss: 0.3680 - learning_rate: 2.5000e-04
# Epoch 24/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.8909 - loss: 0.3204 - val_accuracy: 0.8793 - val_loss: 0.3678 - learning_rate: 2.5000e-04
# Epoch 25/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.8934 - loss: 0.3076 - val_accuracy: 0.8836 - val_loss: 0.3635 - learning_rate: 2.5000e-04
# Epoch 26/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.8983 - loss: 0.3004 - val_accuracy: 0.8857 - val_loss: 0.3638 - learning_rate: 2.5000e-04
# Epoch 27/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.8960 - loss: 0.2987 - val_accuracy: 0.8874 - val_loss: 0.3676 - learning_rate: 2.5000e-04
# Epoch 28/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.8982 - loss: 0.2931 - val_accuracy: 0.8869 - val_loss: 0.3619 - learning_rate: 2.5000e-04
# Epoch 29/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.8999 - loss: 0.2826 - val_accuracy: 0.8936 - val_loss: 0.3467 - learning_rate: 2.5000e-04
# Epoch 30/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.9039 - loss: 0.2784 - val_accuracy: 0.8889 - val_loss: 0.3529 - learning_rate: 2.5000e-04
#
# [VGG_S1] Test Acc: 0.8936 | Time: 759.1s
#
# ==================================================
# Training ResNet | Strategy 1: Full Dataset (with augmentation)
# ==================================================
# Epoch 1/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 57s 110ms/step - accuracy: 0.3914 - loss: 1.7361 - val_accuracy: 0.5097 - val_loss: 1.3327 - learning_rate: 0.0010
# Epoch 2/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.6529 - loss: 0.9744 - val_accuracy: 0.6032 - val_loss: 1.3064 - learning_rate: 0.0010
# Epoch 3/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.7371 - loss: 0.7563 - val_accuracy: 0.5486 - val_loss: 1.4664 - learning_rate: 0.0010
# Epoch 4/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.7822 - loss: 0.6271 - val_accuracy: 0.7199 - val_loss: 0.8581 - learning_rate: 0.0010
# Epoch 5/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.8116 - loss: 0.5472 - val_accuracy: 0.6847 - val_loss: 1.0157 - learning_rate: 0.0010
# Epoch 6/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.8340 - loss: 0.4791 - val_accuracy: 0.7264 - val_loss: 0.8450 - learning_rate: 0.0010
# Epoch 7/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.8541 - loss: 0.4292 - val_accuracy: 0.7956 - val_loss: 0.6119 - learning_rate: 0.0010
# Epoch 8/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.8630 - loss: 0.3937 - val_accuracy: 0.8150 - val_loss: 0.5429 - learning_rate: 0.0010
# Epoch 9/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.8719 - loss: 0.3688 - val_accuracy: 0.7431 - val_loss: 0.8441 - learning_rate: 0.0010
# Epoch 10/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.8865 - loss: 0.3259 - val_accuracy: 0.8366 - val_loss: 0.5046 - learning_rate: 0.0010
# Epoch 11/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.8948 - loss: 0.3060 - val_accuracy: 0.8258 - val_loss: 0.5331 - learning_rate: 0.0010
# Epoch 12/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9050 - loss: 0.2748 - val_accuracy: 0.8374 - val_loss: 0.4961 - learning_rate: 0.0010
# Epoch 13/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9095 - loss: 0.2587 - val_accuracy: 0.8310 - val_loss: 0.5372 - learning_rate: 0.0010
# Epoch 14/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9155 - loss: 0.2423 - val_accuracy: 0.7669 - val_loss: 0.8793 - learning_rate: 0.0010
# Epoch 15/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9245 - loss: 0.2199 - val_accuracy: 0.8430 - val_loss: 0.4773 - learning_rate: 0.0010
# Epoch 16/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9276 - loss: 0.2127 - val_accuracy: 0.8655 - val_loss: 0.4416 - learning_rate: 0.0010
# Epoch 17/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9309 - loss: 0.2030 - val_accuracy: 0.8762 - val_loss: 0.3768 - learning_rate: 0.0010
# Epoch 18/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9356 - loss: 0.1865 - val_accuracy: 0.8704 - val_loss: 0.4120 - learning_rate: 0.0010
# Epoch 19/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9386 - loss: 0.1742 - val_accuracy: 0.8402 - val_loss: 0.5264 - learning_rate: 0.0010
# Epoch 20/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9430 - loss: 0.1608 - val_accuracy: 0.8626 - val_loss: 0.4730 - learning_rate: 0.0010
# Epoch 21/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9600 - loss: 0.1149 - val_accuracy: 0.9022 - val_loss: 0.3209 - learning_rate: 5.0000e-04
# Epoch 22/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9674 - loss: 0.0922 - val_accuracy: 0.9059 - val_loss: 0.3182 - learning_rate: 5.0000e-04
# Epoch 23/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9697 - loss: 0.0850 - val_accuracy: 0.9054 - val_loss: 0.3422 - learning_rate: 5.0000e-04
# Epoch 24/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9727 - loss: 0.0779 - val_accuracy: 0.9036 - val_loss: 0.3325 - learning_rate: 5.0000e-04
# Epoch 25/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9745 - loss: 0.0746 - val_accuracy: 0.9023 - val_loss: 0.3611 - learning_rate: 5.0000e-04
# Epoch 26/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9801 - loss: 0.0575 - val_accuracy: 0.9186 - val_loss: 0.2820 - learning_rate: 2.5000e-04
# Epoch 27/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9854 - loss: 0.0458 - val_accuracy: 0.9170 - val_loss: 0.3139 - learning_rate: 2.5000e-04
# Epoch 28/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9855 - loss: 0.0454 - val_accuracy: 0.9131 - val_loss: 0.3387 - learning_rate: 2.5000e-04
# Epoch 29/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9869 - loss: 0.0402 - val_accuracy: 0.9196 - val_loss: 0.3102 - learning_rate: 2.5000e-04
# Epoch 30/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9894 - loss: 0.0334 - val_accuracy: 0.9233 - val_loss: 0.2860 - learning_rate: 1.2500e-04
#
# [ResNet_S1] Test Acc: 0.9186 | Time: 1022.8s
#
# ==================================================
# Training MobileNet | Strategy 1: Full Dataset (with augmentation)
# ==================================================
# Epoch 1/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 64s 117ms/step - accuracy: 0.3802 - loss: 1.6820 - val_accuracy: 0.1000 - val_loss: 3.6525 - learning_rate: 0.0010
# Epoch 2/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.5870 - loss: 1.1537 - val_accuracy: 0.5599 - val_loss: 1.3243 - learning_rate: 0.0010
# Epoch 3/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.6563 - loss: 0.9649 - val_accuracy: 0.6051 - val_loss: 1.2064 - learning_rate: 0.0010
# Epoch 4/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7053 - loss: 0.8385 - val_accuracy: 0.6797 - val_loss: 0.9389 - learning_rate: 0.0010
# Epoch 5/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7382 - loss: 0.7429 - val_accuracy: 0.6840 - val_loss: 0.9198 - learning_rate: 0.0010
# Epoch 6/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7634 - loss: 0.6832 - val_accuracy: 0.6905 - val_loss: 0.9361 - learning_rate: 0.0010
# Epoch 7/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7797 - loss: 0.6302 - val_accuracy: 0.7115 - val_loss: 0.8454 - learning_rate: 0.0010
# Epoch 8/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7995 - loss: 0.5786 - val_accuracy: 0.7372 - val_loss: 0.8067 - learning_rate: 0.0010
# Epoch 9/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.8051 - loss: 0.5568 - val_accuracy: 0.7766 - val_loss: 0.6725 - learning_rate: 0.0010
# Epoch 10/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.8206 - loss: 0.5226 - val_accuracy: 0.7584 - val_loss: 0.7447 - learning_rate: 0.0010
# Epoch 11/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.8220 - loss: 0.5086 - val_accuracy: 0.7829 - val_loss: 0.6668 - learning_rate: 0.0010
# Epoch 12/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.8334 - loss: 0.4797 - val_accuracy: 0.7980 - val_loss: 0.6091 - learning_rate: 0.0010
# Epoch 13/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.8419 - loss: 0.4529 - val_accuracy: 0.8126 - val_loss: 0.5574 - learning_rate: 0.0010
# Epoch 14/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.8464 - loss: 0.4476 - val_accuracy: 0.7968 - val_loss: 0.6270 - learning_rate: 0.0010
# Epoch 15/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 65ms/step - accuracy: 0.8548 - loss: 0.4142 - val_accuracy: 0.8037 - val_loss: 0.5955 - learning_rate: 0.0010
# Epoch 16/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.8568 - loss: 0.4082 - val_accuracy: 0.7936 - val_loss: 0.6722 - learning_rate: 0.0010
# Epoch 17/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.8727 - loss: 0.3694 - val_accuracy: 0.8425 - val_loss: 0.4816 - learning_rate: 5.0000e-04
# Epoch 18/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 63ms/step - accuracy: 0.8831 - loss: 0.3389 - val_accuracy: 0.8096 - val_loss: 0.5983 - learning_rate: 5.0000e-04
# Epoch 19/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.8845 - loss: 0.3332 - val_accuracy: 0.8390 - val_loss: 0.4876 - learning_rate: 5.0000e-04
# Epoch 20/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.8859 - loss: 0.3242 - val_accuracy: 0.8406 - val_loss: 0.4831 - learning_rate: 5.0000e-04
# Epoch 21/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.8966 - loss: 0.3024 - val_accuracy: 0.8510 - val_loss: 0.4599 - learning_rate: 2.5000e-04
# Epoch 22/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.9029 - loss: 0.2822 - val_accuracy: 0.8518 - val_loss: 0.4638 - learning_rate: 2.5000e-04
# Epoch 23/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.9047 - loss: 0.2774 - val_accuracy: 0.8523 - val_loss: 0.4618 - learning_rate: 2.5000e-04
# Epoch 24/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 65ms/step - accuracy: 0.9019 - loss: 0.2792 - val_accuracy: 0.8533 - val_loss: 0.4549 - learning_rate: 2.5000e-04
# Epoch 25/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.9071 - loss: 0.2734 - val_accuracy: 0.8589 - val_loss: 0.4529 - learning_rate: 2.5000e-04
# Epoch 26/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.9094 - loss: 0.2622 - val_accuracy: 0.8583 - val_loss: 0.4466 - learning_rate: 2.5000e-04
# Epoch 27/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.9060 - loss: 0.2613 - val_accuracy: 0.8559 - val_loss: 0.4436 - learning_rate: 2.5000e-04
# Epoch 28/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.9080 - loss: 0.2572 - val_accuracy: 0.8578 - val_loss: 0.4460 - learning_rate: 2.5000e-04
# Epoch 29/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 65ms/step - accuracy: 0.9140 - loss: 0.2473 - val_accuracy: 0.8589 - val_loss: 0.4392 - learning_rate: 2.5000e-04
# Epoch 30/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.9137 - loss: 0.2461 - val_accuracy: 0.8548 - val_loss: 0.4612 - learning_rate: 2.5000e-04
#
# [MobileNet_S1] Test Acc: 0.8589 | Time: 784.9s
#
# Strategy 1 complete ✓

# %%
# Cell 6: Strategy 2 — Progressive Dataset Revelation (10→25→50→75→100%)

PERCENTAGES = [0.10, 0.25, 0.50, 0.75, 1.00]
EPOCHS_PER_STAGE = 6   # ~30 epochs total across 5 stages

def progressive_train(build_fn, name):
    model = build_fn()
    compile_model(model)
    all_hist = {'accuracy': [], 'val_accuracy': [], 'loss': [], 'val_loss': []}
    start = time.time()

    for pct in PERCENTAGES:
        n = int(len(x_train) * pct)
        # Random subset
        idx = np.random.choice(len(x_train), n, replace=False)
        x_sub, y_sub = x_train[idx], y_train_cat[idx]

        print(f"  {name} | {int(pct*100)}% data ({n} samples)...")
        hist = model.fit(
            x_sub, y_sub,
            validation_data=(x_test, y_test_cat),
            epochs=EPOCHS_PER_STAGE,
            batch_size=128,
            verbose=0
        )
        for k in all_hist:
            all_hist[k].extend(hist.history[k])

    elapsed = time.time() - start
    _, acc = model.evaluate(x_test, y_test_cat, verbose=0)
    print(f"  Final acc: {acc:.4f} | Time: {elapsed:.1f}s")
    return all_hist, acc, elapsed

for name, build_fn in [('VGG', build_vgg), ('ResNet', build_resnet), ('MobileNet', build_mobilenet)]:
    print(f"\n{'='*50}")
    print(f"Training {name} | Strategy 2: Progressive Revelation")
    print('='*50)
    hist, acc, t = progressive_train(build_fn, name)
    results[f"{name}_S2"] = {'history': hist, 'acc': acc, 'time': t}

print("\nStrategy 2 complete ✓")
# Out:
# ==================================================
# Training VGG | Strategy 2: Progressive Revelation
# ==================================================
#   VGG | 10% data (5000 samples)...
#   VGG | 25% data (12500 samples)...
#   VGG | 50% data (25000 samples)...
#   VGG | 75% data (37500 samples)...
#   VGG | 100% data (50000 samples)...
#   Final acc: 0.8424 | Time: 249.5s
#
# ==================================================
# Training ResNet | Strategy 2: Progressive Revelation
# ==================================================
#   ResNet | 10% data (5000 samples)...
#   ResNet | 25% data (12500 samples)...
#   ResNet | 50% data (25000 samples)...
#   ResNet | 75% data (37500 samples)...
#   ResNet | 100% data (50000 samples)...
#   Final acc: 0.7568 | Time: 573.2s
#
# ==================================================
# Training MobileNet | Strategy 2: Progressive Revelation
# ==================================================
#   MobileNet | 10% data (5000 samples)...
#   MobileNet | 25% data (12500 samples)...
#   MobileNet | 50% data (25000 samples)...
#   MobileNet | 75% data (37500 samples)...
#   MobileNet | 100% data (50000 samples)...
#   Final acc: 0.6592 | Time: 214.7s
#
# Strategy 2 complete ✓

# %%
# Cell 7: Strategy 3 — Curriculum Learning by prediction difficulty

def get_difficulty_order(x_data, y_data):
    """
    Train a quick small model, measure per-sample loss
    → sort easy (low loss) to hard (high loss)
    """
    print("  Estimating sample difficulty...")
    quick_model = models.Sequential([
        layers.Conv2D(32, 3, activation='relu', padding='same', input_shape=(32,32,3)),
        layers.MaxPooling2D(2,2),
        layers.Conv2D(64, 3, activation='relu', padding='same'),
        layers.GlobalAveragePooling2D(),
        layers.Dense(10, activation='softmax')
    ])
    quick_model.compile(optimizer='adam', loss='categorical_crossentropy')
    quick_model.fit(x_data, y_data, epochs=5, batch_size=256, verbose=0)

    # Per-sample losses
    losses = []
    bs = 512
    for i in range(0, len(x_data), bs):
        batch_x = x_data[i:i+bs]
        batch_y = y_data[i:i+bs]
        pred = quick_model(batch_x, training=False)
        loss = keras.losses.categorical_crossentropy(batch_y, pred).numpy()
        losses.extend(loss)

    order = np.argsort(losses)  # easy → hard
    return order

CURRICULUM_STAGES = [0.20, 0.50, 0.80, 1.00]   # add harder samples progressively
EPOCHS_PER_CUR    = [8,    7,    8,    7   ]    # ~30 total

def curriculum_train(build_fn, name, difficulty_order):
    model = build_fn()
    compile_model(model)
    all_hist = {'accuracy': [], 'val_accuracy': [], 'loss': [], 'val_loss': []}
    start = time.time()

    for pct, ep in zip(CURRICULUM_STAGES, EPOCHS_PER_CUR):
        n = int(len(x_train) * pct)
        idx = difficulty_order[:n]   # take easiest n samples
        x_sub, y_sub = x_train[idx], y_train_cat[idx]

        print(f"  {name} | {int(pct*100)}% easiest samples ({n})...")
        hist = model.fit(
            x_sub, y_sub,
            validation_data=(x_test, y_test_cat),
            epochs=ep,
            batch_size=128,
            verbose=0
        )
        for k in all_hist:
            all_hist[k].extend(hist.history[k])

    elapsed = time.time() - start
    _, acc = model.evaluate(x_test, y_test_cat, verbose=0)
    print(f"  Final acc: {acc:.4f} | Time: {elapsed:.1f}s")
    return all_hist, acc, elapsed

# Get difficulty order once (shared for all models)
diff_order = get_difficulty_order(x_train, y_train_cat)

for name, build_fn in [('VGG', build_vgg), ('ResNet', build_resnet), ('MobileNet', build_mobilenet)]:
    print(f"\n{'='*50}")
    print(f"Training {name} | Strategy 3: Curriculum Learning")
    print('='*50)
    hist, acc, t = curriculum_train(build_fn, name, diff_order)
    results[f"{name}_S3"] = {'history': hist, 'acc': acc, 'time': t}

print("\nStrategy 3 complete ✓")
# Out:
#   Estimating sample difficulty...
#
# ==================================================
# Training VGG | Strategy 3: Curriculum Learning
# ==================================================
#   VGG | 20% easiest samples (10000)...
#   VGG | 50% easiest samples (25000)...
#   VGG | 80% easiest samples (40000)...
#   VGG | 100% easiest samples (50000)...
#   Final acc: 0.8394 | Time: 270.1s
#
# ==================================================
# Training ResNet | Strategy 3: Curriculum Learning
# ==================================================
#   ResNet | 20% easiest samples (10000)...
#   ResNet | 50% easiest samples (25000)...
#   ResNet | 80% easiest samples (40000)...
#   ResNet | 100% easiest samples (50000)...
#   Final acc: 0.7042 | Time: 651.3s
#
# ==================================================
# Training MobileNet | Strategy 3: Curriculum Learning
# ==================================================
#   MobileNet | 20% easiest samples (10000)...
#   MobileNet | 50% easiest samples (25000)...
#   MobileNet | 80% easiest samples (40000)...
#   MobileNet | 100% easiest samples (50000)...
#   Final acc: 0.7617 | Time: 216.6s
#
# Strategy 3 complete ✓

# %%
# Cell 8: Plot training curves for all combos

fig, axes = plt.subplots(3, 3, figsize=(18, 14))
strats = ['S1', 'S2', 'S3']
strat_names = ['Full Dataset', 'Progressive', 'Curriculum']
models_list = ['VGG', 'ResNet', 'MobileNet']
colors = {'train': '#5C6BC0', 'val': '#EF5350'}

for col, (s, sname) in enumerate(zip(strats, strat_names)):
    for row, mname in enumerate(models_list):
        ax = axes[row][col]
        key = f"{mname}_{s}"
        h = results[key]['history']

        # handle both History object and dict
        hist_dict = h.history if hasattr(h, 'history') else h

        ax.plot(hist_dict['accuracy'],     color=colors['train'], label='Train Acc', lw=2)
        ax.plot(hist_dict['val_accuracy'], color=colors['val'],   label='Val Acc',  lw=2, linestyle='--')
        ax.set_title(f"{mname} — {sname}\nTest acc: {results[key]['acc']:.4f}", fontsize=11)
        ax.set_xlabel('Epoch')
        ax.set_ylabel('Accuracy')
        ax.legend(fontsize=8)
        ax.set_ylim(0, 1)
        ax.grid(True, alpha=0.3)

plt.suptitle("Training Curves: 3 Architectures × 3 Strategies on CIFAR-10", fontsize=14, y=1.01)
plt.tight_layout()
plt.savefig("training_curves.png", dpi=150, bbox_inches='tight')
plt.show()

# %%
# Cell 9: Bar chart comparison

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

model_names  = ['VGG', 'ResNet', 'MobileNet']
strat_labels = ['Full Dataset', 'Progressive', 'Curriculum']
x = np.arange(len(model_names))
width = 0.25
colors_bar = ['#5C6BC0', '#26A69A', '#FFA726']

for i, (s, sl) in enumerate(zip(['S1','S2','S3'], strat_labels)):
    accs  = [results[f"{m}_{s}"]['acc']  for m in model_names]
    times = [results[f"{m}_{s}"]['time'] for m in model_names]
    ax1.bar(x + i*width, accs,  width, label=sl, color=colors_bar[i], alpha=0.85)
    ax2.bar(x + i*width, times, width, label=sl, color=colors_bar[i], alpha=0.85)

ax1.set_title('Test Accuracy Comparison');  ax1.set_ylabel('Accuracy')
ax2.set_title('Training Time (seconds)');   ax2.set_ylabel('Seconds')
for ax in [ax1, ax2]:
    ax.set_xticks(x + width); ax.set_xticklabels(model_names)
    ax.legend(); ax.grid(axis='y', alpha=0.3)

plt.suptitle("Architecture × Strategy Comparison")
plt.tight_layout()
plt.savefig("comparison_bar.png", dpi=150, bbox_inches='tight')
plt.show()

# %%
# Cell 10: Convergence speed — epochs to reach 60% val accuracy

def epochs_to_threshold(hist_dict, threshold=0.60):
    for i, v in enumerate(hist_dict['val_accuracy']):
        if v >= threshold:
            return i + 1
    return len(hist_dict['val_accuracy'])   # never reached

print(f"{'Model':<12} {'Strategy':<15} {'TestAcc':>8} {'EpTo60%':>8} {'Time(s)':>9}")
print("-" * 55)

for mname in ['VGG','ResNet','MobileNet']:
    for s, sname in zip(['S1','S2','S3'],['Full','Progressive','Curriculum']):
        key = f"{mname}_{s}"
        h = results[key]['history']
        hd = h.history if hasattr(h,'history') else h
        ep = epochs_to_threshold(hd)
        print(f"{mname:<12} {sname:<15} {results[key]['acc']:>8.4f} {ep:>8d} {results[key]['time']:>9.1f}")
# Out:
# Model        Strategy         TestAcc  EpTo60%   Time(s)
# -------------------------------------------------------
# VGG          Full              0.8936        4     759.1
# VGG          Progressive       0.8424       11     249.5
# VGG          Curriculum        0.8394       12     270.1
# ResNet       Full              0.9186        2    1022.8
# ResNet       Progressive       0.7568       13     573.2
# ResNet       Curriculum        0.7042       15     651.3
# MobileNet    Full              0.8589        3     784.9
# MobileNet    Progressive       0.6592       16     214.7
# MobileNet    Curriculum        0.7617       18     216.6

# %%
# Cell 11: Generalization gap (train_acc - val_acc at final epoch)

gaps = {}
for mname in ['VGG','ResNet','MobileNet']:
    for s, sname in zip(['S1','S2','S3'],['Full','Progressive','Curriculum']):
        key = f"{mname}_{s}"
        h = results[key]['history']
        hd = h.history if hasattr(h,'history') else h
        gap = hd['accuracy'][-1] - hd['val_accuracy'][-1]
        gaps[f"{mname}\n{sname}"] = gap

plt.figure(figsize=(12, 5))
bars = plt.bar(gaps.keys(), gaps.values(),
               color=['#EF5350' if v > 0.1 else '#66BB6A' for v in gaps.values()],
               alpha=0.85, edgecolor='white')
plt.axhline(0.1, color='orange', linestyle='--', label='Overfit threshold (0.1)')
plt.title("Generalization Gap (Train Acc − Val Acc)\nLower is better")
plt.ylabel("Gap"); plt.legend(); plt.grid(axis='y', alpha=0.3)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig("generalization_gap.png", dpi=150, bbox_inches='tight')
plt.show()

# %%
# Cell 12: Final summary + analysis

import pandas as pd

rows = []
for mname in ['VGG','ResNet','MobileNet']:
    for s, sname in zip(['S1','S2','S3'],['Full Dataset','Progressive','Curriculum']):
        key = f"{mname}_{s}"
        h = results[key]['history']
        hd = h.history if hasattr(h,'history') else h
        gap = hd['accuracy'][-1] - hd['val_accuracy'][-1]
        ep  = epochs_to_threshold(hd)
        rows.append({
            'Architecture' : mname,
            'Strategy'     : sname,
            'Test Acc'     : round(results[key]['acc'], 4),
            'Train Time(s)': round(results[key]['time'], 1),
            'Epochs→60%'   : ep,
            'Gen Gap'      : round(gap, 4)
        })

df = pd.DataFrame(rows)
display(df)
df.to_csv("results_summary.csv", index=False)
print("\nSaved: results_summary.csv")

best = df.loc[df['Test Acc'].idxmax()]
print(f"\n✅ Best: {best['Architecture']} with {best['Strategy']} → {best['Test Acc']:.4f} accuracy")
# Out:
#   Architecture      Strategy  Test Acc  Train Time(s)  Epochs→60%  Gen Gap
# 0          VGG  Full Dataset    0.8936          759.1           4   0.0149
# 1          VGG   Progressive    0.8424          249.5          11   0.0423
# 2          VGG    Curriculum    0.8394          270.1          12   0.0441
# 3       ResNet  Full Dataset    0.9186         1022.8           2   0.0668
# 4       ResNet   Progressive    0.7568          573.2          13   0.2227
# 5       ResNet    Curriculum    0.7042          651.3          15   0.2712
# 6    MobileNet  Full Dataset    0.8589          784.9           3   0.0575
# 7    MobileNet   Progressive    0.6592          214.7          16   0.2531
# 8    MobileNet    Curriculum    0.7617          216.6          18   0.1615
# Saved: results_summary.csv
#
# ✅ Best: ResNet with Full Dataset → 0.9186 accuracy

# %% [markdown]
# ## Observations & Conclusions
#
# ### Convergence Speed
# - **Progressive revelation** converges faster early — model starts with 10% data and builds up, learning clean patterns first.
# - **Curriculum learning** also speeds convergence since easy samples dominate the first stages, producing cleaner gradients.
# - **Full dataset** has all info from epoch 1 but harder samples slow early convergence.
#
# > **Note on stages:** Strategy 3 (Curriculum) uses `20% → 50% → 80% → 100%` sorted by difficulty. Strategy 2 (Progressive) uses `10% → 25% → 50% → 75% → 100%` random subsets. This is intentional — curriculum needs a minimum sample count to estimate difficulty reliably.
#
# ---
#
# ### Accuracy
# - **Full dataset + augmentation** achieves the strongest test accuracy — all data plus augmentation from epoch 1.
# - **Curriculum learning** can match full training by reducing noisy gradients in early epochs.
# - **Progressive revelation** typically sits between the two.
#
# ---
#
# ### Generalization Behaviour
# - **Curriculum learning** has the **smallest generalization gap** (train acc − val acc) — learning on easy samples first prevents overfitting to noisy hard examples.
#  - **VGG** overfits more than ResNet/MobileNet due to its large Dense(512) layers. Augmentation in Strategy 1 helps reduce this.
# - **ResNet and MobileNet** generalize better due to GlobalAveragePooling instead of Flatten+Dense.
#
# ---
#
# ### Architecture Ranking
#
# | Rank | Architecture | Strength | Weakness |
# |------|-------------|----------|----------|
# | 1 | **ResNet** | Best accuracy + generalization via residual connections | Slower than MobileNet |
# | 2 | **MobileNet** | Fastest training, fewest params, competitive accuracy | Slightly lower accuracy |
# | 3 | **VGG-style** | Simple, interpretable | Most params, most prone to overfit |

# %%
# Cell 13: Loss Curves (train loss vs val loss for all 9 combinations)

fig, axes = plt.subplots(3, 3, figsize=(18, 14))
strats = ['S1', 'S2', 'S3']
strat_names = ['Full Dataset', 'Progressive', 'Curriculum']
models_list = ['VGG', 'ResNet', 'MobileNet']

for col, (s, sname) in enumerate(zip(strats, strat_names)):
    for row, mname in enumerate(models_list):
        ax = axes[row][col]
        key = f"{mname}_{s}"
        h = results[key]['history']
        hd = h.history if hasattr(h, 'history') else h

        ax.plot(hd['loss'],     color='#5C6BC0', label='Train Loss', lw=2)
        ax.plot(hd['val_loss'], color='#EF5350', label='Val Loss',   lw=2, linestyle='--')
        ax.set_title(f"{mname} — {sname}", fontsize=11)
        ax.set_xlabel('Epoch')
        ax.set_ylabel('Loss')
        ax.legend(fontsize=8)
        ax.grid(True, alpha=0.3)

plt.suptitle("Loss Curves: 3 Architectures × 3 Strategies on CIFAR-10", fontsize=14, y=1.01)
plt.tight_layout()
plt.savefig("loss_curves.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved: loss_curves.png")
# Out:
# Saved: loss_curves.png

# %%
# Cell 14: Confusion Matrices (best model per strategy)
# Plots one confusion matrix per strategy using the best-performing architecture

from sklearn.metrics import confusion_matrix
import seaborn as sns

CLASS_NAMES = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

# Identify best architecture per strategy by test accuracy
best_per_strategy = {}
for s, sname in zip(['S1','S2','S3'], ['Full Dataset','Progressive','Curriculum']):
    best_model_name = max(['VGG','ResNet','MobileNet'],
                          key=lambda m: results[f"{m}_{s}"]['acc'])
    best_per_strategy[s] = (best_model_name, sname)

fig, axes = plt.subplots(1, 3, figsize=(20, 6))

for col, (s, (mname, sname)) in enumerate(best_per_strategy.items()):
    # Rebuild and retrain best model to get predictions
    build_fn = {'VGG': build_vgg, 'ResNet': build_resnet, 'MobileNet': build_mobilenet}[mname]
    model = build_fn()
    compile_model(model)

    # Train quickly using full data for predictions
    model.fit(x_train, y_train_cat, epochs=30, batch_size=64,
              callbacks=[keras.callbacks.EarlyStopping(patience=8, restore_best_weights=True)],
              verbose=0)

    y_pred = np.argmax(model.predict(x_test, verbose=0), axis=1)
    y_true = y_test.flatten()

    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', ax=axes[col],
                xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
                cmap='Blues', linewidths=0.5)
    axes[col].set_title(f"{mname} — {sname}\nTest Acc: {results[f'{mname}_{s}']['acc']:.4f}", fontsize=11)
    axes[col].set_xlabel('Predicted Label')
    axes[col].set_ylabel('True Label')
    axes[col].tick_params(axis='x', rotation=45)
    axes[col].tick_params(axis='y', rotation=0)

plt.suptitle("Confusion Matrices — Best Model per Strategy", fontsize=14)
plt.tight_layout()
plt.savefig("confusion_matrices.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved: confusion_matrices.png")
# Out:
# Saved: confusion_matrices.png

# %%
# Cell 15: Precision, Recall, F1 Score for all 9 combinations

from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

print(f"{'Model':<12} {'Strategy':<15} {'Accuracy':>9} {'Precision':>10} {'Recall':>8} {'F1 Score':>10}")
print("-" * 68)

classification_results = []

for mname, build_fn in [('VGG', build_vgg), ('ResNet', build_resnet), ('MobileNet', build_mobilenet)]:
    for s, sname in zip(['S1','S2','S3'], ['Full Dataset','Progressive','Curriculum']):

        model = build_fn()
        compile_model(model)
        model.fit(x_train, y_train_cat, epochs=30, batch_size=64,
                  callbacks=[keras.callbacks.EarlyStopping(patience=8, restore_best_weights=True)],
                  verbose=0)

        y_pred = np.argmax(model.predict(x_test, verbose=0), axis=1)
        y_true = y_test.flatten()

        acc  = results[f"{mname}_{s}"]['acc']
        prec = precision_score(y_true, y_pred, average='weighted')
        rec  = recall_score(y_true, y_pred, average='weighted')
        f1   = f1_score(y_true, y_pred, average='weighted')

        print(f"{mname:<12} {sname:<15} {acc:>9.4f} {prec:>10.4f} {rec:>8.4f} {f1:>10.4f}")
        classification_results.append({
            'Architecture': mname, 'Strategy': sname,
            'Accuracy': round(acc,4), 'Precision': round(prec,4),
            'Recall': round(rec,4), 'F1 Score': round(f1,4)
        })

clf_df = pd.DataFrame(classification_results)
clf_df.to_csv("classification_metrics.csv", index=False)
print("\nSaved: classification_metrics.csv")
# Out:
# Model        Strategy         Accuracy  Precision   Recall   F1 Score
# --------------------------------------------------------------------
# VGG          Full Dataset       0.8936     0.8562   0.8564     0.8554
# VGG          Progressive        0.8424     0.8644   0.8620     0.8623
# VGG          Curriculum         0.8394     0.8597   0.8590     0.8581
# ResNet       Full Dataset       0.9186     0.8551   0.8367     0.8395
# ResNet       Progressive        0.7568     0.8603   0.8389     0.8399
# ResNet       Curriculum         0.7042     0.8313   0.8081     0.8084
# MobileNet    Full Dataset       0.8589     0.8060   0.7983     0.7996
# MobileNet    Progressive        0.6592     0.8040   0.7861     0.7847
# MobileNet    Curriculum         0.7617     0.8034   0.7926     0.7934
#
# Saved: classification_metrics.csv

# %%
# Cell 16: Comparison with known baseline models on CIFAR-10

baseline_models = {
    'Simple CNN (Baseline)'     : 0.700,
    'VGG-16 (Literature)'       : 0.930,
    'ResNet-56 (Literature)'    : 0.927,
    'MobileNetV2 (Literature)'  : 0.912,
}

# Best result from each of our architectures (best strategy)
our_best = {}
for mname in ['VGG', 'ResNet', 'MobileNet']:
    best_acc = max(results[f"{mname}_{s}"]['acc'] for s in ['S1','S2','S3'])
    our_best[f"{mname} (Ours — Best)"] = best_acc

all_models = {**baseline_models, **our_best}

fig, ax = plt.subplots(figsize=(12, 6))
colors = ['#B0BEC5' if 'Literature' in k or 'Baseline' in k else '#5C6BC0'
          for k in all_models.keys()]
bars = ax.bar(all_models.keys(), all_models.values(),
              color=colors, alpha=0.88, edgecolor='white', width=0.55)

ax.axhline(0.70, color='gray', linestyle=':', alpha=0.5, label='Simple CNN Baseline (0.70)')
ax.set_ylim(0.60, 1.00)
ax.set_ylabel('Test Accuracy')
ax.set_title('Our Models vs. Known CIFAR-10 Baselines', fontsize=13)
ax.tick_params(axis='x', rotation=30)
ax.grid(axis='y', alpha=0.3)

for bar, val in zip(bars, all_models.values()):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.005,
            f'{val:.3f}', ha='center', va='bottom', fontsize=9)

from matplotlib.patches import Patch
legend_elements = [Patch(facecolor='#B0BEC5', label='Literature / Baseline'),
                   Patch(facecolor='#5C6BC0', label='Our Models')]
ax.legend(handles=legend_elements)
plt.tight_layout()
plt.savefig("baseline_comparison.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved: baseline_comparison.png")
# Out:
# Saved: baseline_comparison.png
